# %%
import os
import pandas as pd

# %%
cwd = os.getcwd()
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join(BASE_DIR, 'cache')
working_file = os.path.join(CACHE_DIR, 'box-office-ranking-dataset.csv')
output_file = os.path.join(CACHE_DIR, 'box-office-ranking-cleaned-dataset.csv')

# %%
df = pd.read_csv(working_file)

# %%
df.head(n=999)
# Out:
#      Rank                                 Release Group       Worldwide  \
# 0       1                                   Toy Story 3  $1,066,969,703
# 1       2                           Alice in Wonderland  $1,025,467,110
# 2       3  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3       4                                     Inception    $826,137,188
# 4       5                           Shrek Forever After    $752,600,867
# ..    ...                                           ...             ...
# 994   410                                          Zama        $489,692
# 995   411                                    Beach Rats        $486,623
# 996   412                                   The Journey        $482,209
# 997   413                        DCI 2017 Tour Premeire        $467,817
# 998   414               Eric Clapton: A Life in 12 Bars        $459,088
#
#          Domestic      %       Foreign    %.1  \
# 0    $415,004,880  38.9%  $651,964,823  61.1%
# 1    $334,191,110  32.6%  $691,276,000  67.4%
# 2    $295,983,305  30.3%  $680,553,613  69.7%
# 3    $292,576,195  35.4%  $533,560,993  64.6%
# 4    $238,736,787  31.7%  $513,864,080  68.3%
# ..            ...    ...           ...    ...
# 994      $200,600    41%      $289,092    59%
# 995      $473,771  97.4%       $12,852   2.6%
# 996      $155,475  32.2%      $326,734  67.8%
# 997      $467,817   100%             -      -
# 998             -      -      $459,088   100%
#
#                             filename  year
# 0    2010_boxofficemojo_rankings.csv  2010
# 1    2010_boxofficemojo_rankings.csv  2010
# 2    2010_boxofficemojo_rankings.csv  2010
# 3    2010_boxofficemojo_rankings.csv  2010
# 4    2010_boxofficemojo_rankings.csv  2010
# ..                               ...   ...
# 994  2017_boxofficemojo_rankings.csv  2017
# 995  2017_boxofficemojo_rankings.csv  2017
# 996  2017_boxofficemojo_rankings.csv  2017
# 997  2017_boxofficemojo_rankings.csv  2017
# 998  2017_boxofficemojo_rankings.csv  2017
#
# [999 rows x 9 columns]

# %%
df['Rank'] = -1
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0    -1                                   Toy Story 3  $1,066,969,703
# 1    -1                           Alice in Wonderland  $1,025,467,110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3    -1                                     Inception    $826,137,188
# 4    -1                           Shrek Forever After    $752,600,867
#
#        Domestic      %       Foreign    %.1                         filename  \
# 0  $415,004,880  38.9%  $651,964,823  61.1%  2010_boxofficemojo_rankings.csv
# 1  $334,191,110  32.6%  $691,276,000  67.4%  2010_boxofficemojo_rankings.csv
# 2  $295,983,305  30.3%  $680,553,613  69.7%  2010_boxofficemojo_rankings.csv
# 3  $292,576,195  35.4%  $533,560,993  64.6%  2010_boxofficemojo_rankings.csv
# 4  $238,736,787  31.7%  $513,864,080  68.3%  2010_boxofficemojo_rankings.csv
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %%
df['Domestic %'] = df['%']
df['Foreign %'] = df['%.1']
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0    -1                                   Toy Story 3  $1,066,969,703
# 1    -1                           Alice in Wonderland  $1,025,467,110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3    -1                                     Inception    $826,137,188
# 4    -1                           Shrek Forever After    $752,600,867
#
#        Domestic      %       Foreign    %.1                         filename  \
# 0  $415,004,880  38.9%  $651,964,823  61.1%  2010_boxofficemojo_rankings.csv
# 1  $334,191,110  32.6%  $691,276,000  67.4%  2010_boxofficemojo_rankings.csv
# 2  $295,983,305  30.3%  $680,553,613  69.7%  2010_boxofficemojo_rankings.csv
# 3  $292,576,195  35.4%  $533,560,993  64.6%  2010_boxofficemojo_rankings.csv
# 4  $238,736,787  31.7%  $513,864,080  68.3%  2010_boxofficemojo_rankings.csv
#
#    year Domestic % Foreign %
# 0  2010      38.9%     61.1%
# 1  2010      32.6%     67.4%
# 2  2010      30.3%     69.7%
# 3  2010      35.4%     64.6%
# 4  2010      31.7%     68.3%

# %%
df.drop(columns=['%', '%.1'], inplace=True)
df.head()
# Out:
#    Rank                                 Release Group       Worldwide  \
# 0    -1                                   Toy Story 3  $1,066,969,703
# 1    -1                           Alice in Wonderland  $1,025,467,110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1    $976,536,918
# 3    -1                                     Inception    $826,137,188
# 4    -1                           Shrek Forever After    $752,600,867
#
#        Domestic       Foreign                         filename  year  \
# 0  $415,004,880  $651,964,823  2010_boxofficemojo_rankings.csv  2010
# 1  $334,191,110  $691,276,000  2010_boxofficemojo_rankings.csv  2010
# 2  $295,983,305  $680,553,613  2010_boxofficemojo_rankings.csv  2010
# 3  $292,576,195  $533,560,993  2010_boxofficemojo_rankings.csv  2010
# 4  $238,736,787  $513,864,080  2010_boxofficemojo_rankings.csv  2010
#
#   Domestic % Foreign %
# 0      38.9%     61.1%
# 1      32.6%     67.4%
# 2      30.3%     69.7%
# 3      35.4%     64.6%
# 4      31.7%     68.3%

# %%
to_clean_cols = ['Worldwide', 'Domestic', 'Foreign']


def currency_str_to_int(current_value):
    currency_value = current_value.replace("$", "").replace(",", "")
    try:
        currency_value = int(currency_value)
    except:
        currency_value = 0
    return currency_value


def clean_col(row):
    for col in to_clean_cols:
        current_value = row[col]
        row[col] = currency_str_to_int(current_value)
    return(row)


df_cleaned = df.apply(clean_col, axis=1)
df_cleaned.head()
# Out:
#    Rank                                 Release Group   Worldwide   Domestic  \
# 0    -1                                   Toy Story 3  1066969703  415004880
# 1    -1                           Alice in Wonderland  1025467110  334191110
# 2    -1  Harry Potter and the Deathly Hallows: Part 1   976536918  295983305
# 3    -1                                     Inception   826137188  292576195
# 4    -1                           Shrek Forever After   752600867  238736787
#
#      Foreign                         filename  year Domestic % Foreign %
# 0  651964823  2010_boxofficemojo_rankings.csv  2010      38.9%     61.1%
# 1  691276000  2010_boxofficemojo_rankings.csv  2010      32.6%     67.4%
# 2  680553613  2010_boxofficemojo_rankings.csv  2010      30.3%     69.7%
# 3  533560993  2010_boxofficemojo_rankings.csv  2010      35.4%     64.6%
# 4  513864080  2010_boxofficemojo_rankings.csv  2010      31.7%     68.3%

# %%
df_cleaned.dtypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Foreign           int64
# filename         object
# year              int64
# Domestic %       object
# Foreign %        object
# dtype: object

# %%
df_cleaned.sort_values(by=['Worldwide'], inplace=True, ascending=False)
df_cleaned.head()
# Out:
#       Rank                               Release Group   Worldwide   Domestic  \
# 5746    -1                           Avengers: Endgame  2797800564  858373000
# 6522    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2724    -1                      Avengers: Infinity War  2048359754  678815482
# 6523    -1                              Jurassic World  1670400637  652270625
# 5747    -1                               The Lion King  1656943394  543638043
#
#          Foreign                         filename  year Domestic % Foreign %
# 5746  1939427564  2019_boxofficemojo_rankings.csv  2019      30.7%     69.3%
# 6522  1131561399  2015_boxofficemojo_rankings.csv  2015      45.3%     54.7%
# 2724  1369544272  2018_boxofficemojo_rankings.csv  2018      33.1%     66.9%
# 6523  1018130012  2015_boxofficemojo_rankings.csv  2015        39%       61%
# 5747  1113305351  2019_boxofficemojo_rankings.csv  2019      32.8%     67.2%

# %%
df_cleaned.reset_index(inplace=True, drop=True)
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0    -1                           Avengers: Endgame  2797800564  858373000
# 1    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2    -1                      Avengers: Infinity War  2048359754  678815482
# 3    -1                              Jurassic World  1670400637  652270625
# 4    -1                               The Lion King  1656943394  543638043
#
#       Foreign                         filename  year Domestic % Foreign %
# 0  1939427564  2019_boxofficemojo_rankings.csv  2019      30.7%     69.3%
# 1  1131561399  2015_boxofficemojo_rankings.csv  2015      45.3%     54.7%
# 2  1369544272  2018_boxofficemojo_rankings.csv  2018      33.1%     66.9%
# 3  1018130012  2015_boxofficemojo_rankings.csv  2015        39%       61%
# 4  1113305351  2019_boxofficemojo_rankings.csv  2019      32.8%     67.2%

# %%
df_cleaned['Rank'] = df_cleaned.index + 1
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign                         filename  year Domestic % Foreign %
# 0  1939427564  2019_boxofficemojo_rankings.csv  2019      30.7%     69.3%
# 1  1131561399  2015_boxofficemojo_rankings.csv  2015      45.3%     54.7%
# 2  1369544272  2018_boxofficemojo_rankings.csv  2018      33.1%     66.9%
# 3  1018130012  2015_boxofficemojo_rankings.csv  2015        39%       61%
# 4  1113305351  2019_boxofficemojo_rankings.csv  2019      32.8%     67.2%

# %%
df_cleaned['Domestic %'] = df_cleaned['Domestic'] / df_cleaned['Worldwide']
df_cleaned['Foreign %'] = df_cleaned['Foreign'] / df_cleaned['Worldwide']
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign                         filename  year  Domestic %  Foreign %
# 0  1939427564  2019_boxofficemojo_rankings.csv  2019    0.306803   0.693197
# 1  1131561399  2015_boxofficemojo_rankings.csv  2015    0.452882   0.547118
# 2  1369544272  2018_boxofficemojo_rankings.csv  2018    0.331395   0.668605
# 3  1018130012  2015_boxofficemojo_rankings.csv  2015    0.390488   0.609512
# 4  1113305351  2019_boxofficemojo_rankings.csv  2019    0.328097   0.671903

# %%
df_cleaned.dtypes
# Out:
# Rank               int64
# Release Group     object
# Worldwide          int64
# Domestic           int64
# Foreign            int64
# filename          object
# year               int64
# Domestic %       float64
# Foreign %        float64
# dtype: object

# %%
df_cleaned.to_csv(output_file, index=False)
